# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanyaraja06/Python-Projects_10/blob/main/Machine_learning_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/content/Dataset .csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram
axes[0].hist(df['Aggregate rating'], bins=25, color='steelblue', edgecolor='black')
axes[0].set_xlabel('Aggregate Rating', fontsize=11)
axes[0].set_ylabel('Frequency', fontsize=11)
axes[0].set_title('Distribution of Restaurant Ratings', fontsize=12, fontweight='bold')
axes[0].grid(axis='y', alpha=0.3)

# Box plot
axes[1].boxplot(df['Aggregate rating'], vert=True)
axes[1].set_ylabel('Aggregate Rating', fontsize=11)
axes[1].set_title('Box Plot of Restaurant Ratings', fontsize=12, fontweight='bold')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
data = df.copy()

# Check for missing values
print("Missing Values Count:")
print("="*50)
missing = data.isnull().sum()
# Out:
# Missing Values Count:
# ...

# %%
data = df.copy()
print("Missing Values Count:")
print("="*50)
missing = data.isnull().sum()
missing_data = pd.DataFrame({
    'Column': missing.index,
    'Missing_Count': missing.values,
    'Percentage': (missing.values / len(data) * 100).round(2)
})
missing_data = missing_data[missing_data['Missing_Count'] > 0].sort_values('Missing_Count', ascending=False)

if len(missing_data) > 0:
    print(missing_data.to_string(index=False))
else:
    print("No missing values found!")
# Out:
# Missing Values Count:
# ...
#   Column  Missing_Count  Percentage
# Cuisines              9        0.09

# %%
numerical_columns = data.select_dtypes(include=[np.number]).columns
for col in numerical_columns:
    if data[col].isnull().sum() > 0:
        median_value = data[col].median()
        data[col].fillna(median_value, inplace=True)
        print(f"Filled {col} with median: {median_value}")

categorical_columns = data.select_dtypes(include=['object']).columns
for col in categorical_columns:
    if data[col].isnull().sum() > 0:
        if col == 'Cuisines':
            data[col].fillna('Unknown', inplace=True)
            print(f"Filled {col} with 'Unknown'")
        else:
            mode_value = data[col].mode()[0] if len(data[col].mode()) > 0 else 'Unknown'
            data[col].fillna(mode_value, inplace=True)
            print(f"Filled {col} with mode: {mode_value}")

print("\nMissing values handled successfully!")
# Out:
# Filled Cuisines with 'Unknown'
#
# Missing values handled successfully!
# /tmp/ipython-input-1090362367.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna('Unknown', inplace=True)

# %%
target = 'Aggregate rating'

# Select relevant features
selected_features = []

# Numerical features
num_features = ['Average Cost for two', 'Price range', 'Votes', 'Latitude', 'Longitude']
for feature in num_features:
    if feature in data.columns:
        selected_features.append(feature)

# Categorical features
cat_features = ['Has Table booking', 'Has Online delivery', 'Is delivering now',
                'Switch to order menu', 'Country Code', 'City']
for feature in cat_features:
    if feature in data.columns:
        selected_features.append(feature)

print("Selected Features:")
print("="*50)
for i, feature in enumerate(selected_features, 1):
    print(f"{i}. {feature}")
# Out:
# Selected Features:
# ...
# 1. Average Cost for two
# 2. Price range
# 3. Votes
# 4. Latitude
# 5. Longitude
# 6. Has Table booking
# 7. Has Online delivery
# 8. Is delivering now
# 9. Switch to order menu
# 10. Country Code
# 11. City

# %%
# Create Cuisine Count feature
if 'Cuisines' in data.columns:
    # Count number of cuisines by splitting on comma
    data['Cuisine_Count'] = data['Cuisines'].apply(
        lambda x: len(str(x).split(',')) if pd.notna(x) and str(x) != 'Unknown' else 0
    )
    selected_features.append('Cuisine_Count')
    print("Created feature: Cuisine_Count")
    print(f"Range: {data['Cuisine_Count'].min()} to {data['Cuisine_Count'].max()}")
    print(f"Average cuisines per restaurant: {data['Cuisine_Count'].mean():.2f}")

print(f"\nTotal Features: {len(selected_features)}")
# Out:
# Created feature: Cuisine_Count
# Range: 0 to 8
# Average cuisines per restaurant: 2.06
#
# Total Features: 12

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
# Encode categorical variables
label_encoders = {}

print("Encoding Categorical Variables:")
print("="*50)

for feature in selected_features:
    if data[feature].dtype == 'object':
        le = LabelEncoder()
        data[feature] = le.fit_transform(data[feature].astype(str))
        label_encoders[feature] = le
        print(f"Encoded: {feature} ({len(le.classes_)} unique values)")

print("\nEncoding completed!")
# Out:
# Encoding Categorical Variables:
# ...
# Encoded: Has Table booking (2 unique values)
# Encoded: Has Online delivery (2 unique values)
# Encoded: Is delivering now (2 unique values)
# Encoded: Switch to order menu (1 unique values)
# Encoded: City (141 unique values)
#
# Encoding completed!

# %%
# Prepare feature matrix and target vector
X = data[selected_features]
y = data[target]

print("Data Preparation Summary:")
print("="*50)
print(f"Features (X) shape: {X.shape}")
print(f"Target (y) shape: {y.shape}")
print(f"\nFeature Matrix Preview:")
X.head()
# Out:
# Data Preparation Summary:
# ...
# Features (X) shape: (9551, 12)
# Target (y) shape: (9551,)
#
# Feature Matrix Preview:
#    Average Cost for two  Price range  Votes   Latitude   Longitude  \
# 0                  1100            3    314  14.565443  121.027535
# 1                  1200            3    591  14.553708  121.014101
# 2                  4000            4    270  14.581404  121.056831
# 3                  1500            4    365  14.585318  121.056475
# 4                  1500            4    229  14.584450  121.057508
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# 0                  1                    0                  0
# 1                  1                    0                  0
# 2                  1                    0                  0
# 3                  0                    0                  0
# 4                  1                    0                  0
#
#    Switch to order menu  Country Code  City  Cuisine_Count
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,    # 20% for testing
    random_state=42   # For reproducibility
)

print("Data Split Summary:")
print("="*50)
print(f"Training samples: {X_train.shape[0]} ({(X_train.shape[0]/X.shape[0]*100):.1f}%)")
print(f"Testing samples: {X_test.shape[0]} ({(X_test.shape[0]/X.shape[0]*100):.1f}%)")
print(f"\nFeatures: {X_train.shape[1]}")
print(f"\nTraining target statistics:")
print(y_train.describe())
# Out:
# Data Split Summary:
# ...
# Training samples: 7640 (80.0%)
# Testing samples: 1911 (20.0%)
#
# Features: 12
#
# Training target statistics:
# count    7640.000000
# mean        2.659987
# std         1.518231
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
# Initialize Random Forest Regressor
model = RandomForestRegressor(
    n_estimators=100,      # Number of trees in the forest
    max_depth=10,          # Maximum depth of each tree
    random_state=42,       # For reproducibility
    n_jobs=-1              # Use all CPU cores
)

print("Model: Random Forest Regressor")
print("="*50)
print("Hyperparameters:")
print(f"  - Number of trees: 100")
print(f"  - Max depth: 10")
print(f"  - Random state: 42")
print("\nTraining model...")

# Train the model
model.fit(X_train, y_train)

print("✓ Model trained successfully!")
# Out:
# Model: Random Forest Regressor
# ...
# Hyperparameters:
#   - Number of trees: 100
#   - Max depth: 10
#   - Random state: 42
#
# Training model...
# ✓ Model trained successfully!

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

print("Predictions generated!")
print(f"Training predictions: {len(y_train_pred)}")
print(f"Testing predictions: {len(y_test_pred)}")
# Out:
# Predictions generated!
# Training predictions: 7640
# Testing predictions: 1911

# %%
# Calculate evaluation metrics
# Training metrics
train_mse = mean_squared_error(y_train, y_train_pred)
train_rmse = np.sqrt(train_mse)
train_mae = mean_absolute_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)

# Testing metrics
test_mse = mean_squared_error(y_test, y_test_pred)
test_rmse = np.sqrt(test_mse)
test_mae = mean_absolute_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)

print("Model Performance Evaluation")
print("="*60)
print("\nTRAINING SET PERFORMANCE:")
print("-" * 60)
print(f"Mean Squared Error (MSE):     {train_mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {train_rmse:.4f}")
print(f"Mean Absolute Error (MAE):     {train_mae:.4f}")
print(f"R² Score:                      {train_r2:.4f}")

print("\nTESTING SET PERFORMANCE:")
print("-" * 60)
print(f"Mean Squared Error (MSE):     {test_mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {test_rmse:.4f}")
print(f"Mean Absolute Error (MAE):     {test_mae:.4f}")
print(f"R² Score:                      {test_r2:.4f}")

print("\n" + "="*60)
print("INTERPRETATION:")
print(f"- The model explains {test_r2*100:.2f}% of variance in ratings")
print(f"- Average prediction error: ±{test_mae:.4f} rating points")
print(f"- RMSE penalizes larger errors more than MAE")
# Out:
# Model Performance Evaluation
# ...
#
# TRAINING SET PERFORMANCE:
# ------------------------------------------------------------
# Mean Squared Error (MSE):     0.0716
# Root Mean Squared Error (RMSE): 0.2677
# Mean Absolute Error (MAE):     0.1719
# R² Score:                      0.9689
#
# TESTING SET PERFORMANCE:
# ------------------------------------------------------------
# Mean Squared Error (MSE):     0.0942
# Root Mean Squared Error (RMSE): 0.3069
# Mean Absolute Error (MAE):     0.2012
# R² Score:                      0.9586
#
# ...
# INTERPRETATION:
# - The model explains 95.86% of variance in ratings
# - Average prediction error: ±0.2012 rating points
# - RMSE penalizes larger errors more than MAE

# %%
# Performance visualization
metrics_df = pd.DataFrame({
    'Metric': ['RMSE', 'MAE', 'R² Score'],
    'Training': [train_rmse, train_mae, train_r2],
    'Testing': [test_rmse, test_mae, test_r2]
})

fig, ax = plt.subplots(figsize=(10, 6))
x = np.arange(len(metrics_df))
width = 0.35

ax.bar(x - width/2, metrics_df['Training'], width, label='Training', color='skyblue', edgecolor='black')
ax.bar(x + width/2, metrics_df['Testing'], width, label='Testing', color='coral', edgecolor='black')

ax.set_xlabel('Metrics', fontsize=12, fontweight='bold')
ax.set_ylabel('Score', fontsize=12, fontweight='bold')
ax.set_title('Model Performance Metrics Comparison', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(metrics_df['Metric'])
ax.legend(fontsize=11)
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Scatter plot: Actual vs Predicted
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_test_pred, alpha=0.6, edgecolors='black', linewidths=0.5, s=60)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()],
         'r--', lw=2, label='Perfect Prediction Line')
plt.xlabel('Actual Ratings', fontsize=12, fontweight='bold')
plt.ylabel('Predicted Ratings', fontsize=12, fontweight='bold')
plt.title('Actual vs Predicted Restaurant Ratings', fontsize=14, fontweight='bold')
plt.legend(fontsize=11)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Note: Points closer to the red line indicate better predictions")
# Out:
# Note: Points closer to the red line indicate better predictions

# %%
# Calculate residuals
residuals = y_test - y_test_pred

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Residual plot
axes[0].scatter(y_test_pred, residuals, alpha=0.6, edgecolors='black', linewidths=0.5)
axes[0].axhline(y=0, color='red', linestyle='--', linewidth=2)
axes[0].set_xlabel('Predicted Ratings', fontsize=11, fontweight='bold')
axes[0].set_ylabel('Residuals', fontsize=11, fontweight='bold')
axes[0].set_title('Residual Plot', fontsize=12, fontweight='bold')
axes[0].grid(True, alpha=0.3)

# Residual distribution
axes[1].hist(residuals, bins=30, color='steelblue', edgecolor='black', alpha=0.7)
axes[1].axvline(x=0, color='red', linestyle='--', linewidth=2)
axes[1].set_xlabel('Residuals', fontsize=11, fontweight='bold')
axes[1].set_ylabel('Frequency', fontsize=11, fontweight='bold')
axes[1].set_title('Residual Distribution', fontsize=12, fontweight='bold')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

print(f"Residual Statistics:")
print(f"  Mean: {residuals.mean():.4f} (close to 0 is good)")
print(f"  Std Dev: {residuals.std():.4f}")
# Out:
# Residual Statistics:
#   Mean: 0.0101 (close to 0 is good)
#   Std Dev: 0.3068

# %%
# Get feature importances
feature_importance = pd.DataFrame({
    'Feature': selected_features,
    'Importance': model.feature_importances_
}).sort_values('Importance', ascending=False)

print("Feature Importance Ranking")
print("="*60)
for i, row in feature_importance.iterrows():
    print(f"{row['Feature']:30s} : {row['Importance']:.4f}")

# Display as table
print("\n")
feature_importance
# Out:
# Feature Importance Ranking
# ...
# Votes                          : 0.9724
# Longitude                      : 0.0104
# Latitude                       : 0.0070
# Average Cost for two           : 0.0035
# Country Code                   : 0.0034
# City                           : 0.0013
# Cuisine_Count                  : 0.0007
# Price range                    : 0.0004
# Has Online delivery            : 0.0004
# Has Table booking              : 0.0002
# Is delivering now              : 0.0001
# Switch to order menu           : 0.0000
#                  Feature  Importance
# 2                  Votes    0.972432
# 4              Longitude    0.010416
# 3               Latitude    0.006971
# 0   Average Cost for two    0.003538
# 9           Country Code    0.003430
# 10                  City    0.001347
# 11         Cuisine_Count    0.000738
# 1            Price range    0.000446
# 6    Has Online delivery    0.000375
# 5      Has Table booking    0.000245
# ...

# %%
# Visualize feature importance
plt.figure(figsize=(10, 8))
plt.barh(feature_importance['Feature'], feature_importance['Importance'],
         color='steelblue', edgecolor='black')
plt.xlabel('Importance Score', fontsize=12, fontweight='bold')
plt.ylabel('Features', fontsize=12, fontweight='bold')
plt.title('Feature Importance - Random Forest Model', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Display top 5 features
top_5_features = feature_importance.head(5)

print("\nTOP 5 MOST INFLUENTIAL FEATURES:")
print("="*60)
for i, (idx, row) in enumerate(top_5_features.iterrows(), 1):
    print(f"{i}. {row['Feature']}")
    print(f"   Importance: {row['Importance']:.4f} ({row['Importance']*100:.2f}%)")
    print()

# Better visualization - Horizontal bar chart with percentages
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Chart 1: Top 5 Features Bar Chart
colors_bar = plt.cm.Set3(range(len(top_5_features)))
bars = axes[0].barh(top_5_features['Feature'], top_5_features['Importance'],
                     color=colors_bar, edgecolor='black', linewidth=1.5)
axes[0].set_xlabel('Importance Score', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Features', fontsize=12, fontweight='bold')
axes[0].set_title('Top 5 Most Important Features', fontsize=13, fontweight='bold')
axes[0].invert_yaxis()
axes[0].grid(axis='x', alpha=0.3, linestyle='--')

# Add value labels on bars
for bar in bars:
    width = bar.get_width()
    axes[0].text(width, bar.get_y() + bar.get_height()/2,
                f'{width:.4f}', ha='left', va='center', fontsize=10, fontweight='bold')

# Chart 2: Percentage Contribution
total_importance = top_5_features['Importance'].sum()
percentages = (top_5_features['Importance'] / total_importance * 100).values
bars2 = axes[1].barh(top_5_features['Feature'], percentages,
                      color=colors_bar, edgecolor='black', linewidth=1.5)
axes[1].set_xlabel('Contribution (%)', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Features', fontsize=12, fontweight='bold')
axes[1].set_title('Relative Importance Among Top 5 Features', fontsize=13, fontweight='bold')
axes[1].invert_yaxis()
axes[1].grid(axis='x', alpha=0.3, linestyle='--')

# Add percentage labels on bars
for bar in bars2:
    width = bar.get_width()
    axes[1].text(width, bar.get_y() + bar.get_height()/2,
                f'{width:.1f}%', ha='left', va='center', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

print(f"\nNote: These top 5 features contribute most to predicting restaurant ratings")
# Out:
# TOP 5 MOST INFLUENTIAL FEATURES:
# ...
# 1. Votes
#    Importance: 0.9724 (97.24%)
#
# 2. Longitude
#    Importance: 0.0104 (1.04%)
#
# 3. Latitude
#    Importance: 0.0070 (0.70%)
#
# 4. Average Cost for two
#    Importance: 0.0035 (0.35%)
#
# 5. Country Code
#    Importance: 0.0034 (0.34%)
# Note: These top 5 features contribute most to predicting restaurant ratings

# %%
print("="*70)
print("PROJECT SUMMARY - RESTAURANT RATING PREDICTION")
print("="*70)

print("\n📊 DATASET INFORMATION:")
print("-" * 70)
print(f"Total Restaurants Analyzed: {len(data):,}")
print(f"Number of Features Used: {len(selected_features)}")
print(f"Training Samples: {len(X_train):,}")
print(f"Testing Samples: {len(X_test):,}")

print("\n🤖 MODEL INFORMATION:")
print("-" * 70)
print(f"Algorithm: Random Forest Regressor")
print(f"Number of Trees: 100")
print(f"Maximum Tree Depth: 10")

print("\n📈 MODEL PERFORMANCE:")
print("-" * 70)
print(f"R² Score: {test_r2:.4f}")
print(f"RMSE: {test_rmse:.4f}")
print(f"MAE: {test_mae:.4f}")

# Performance interpretation
if test_r2 > 0.7:
    performance = "Excellent"
elif test_r2 > 0.5:
    performance = "Good"
elif test_r2 > 0.3:
    performance = "Moderate"
else:
    performance = "Needs Improvement"

print(f"\nPerformance Rating: {performance}")
print(f"Variance Explained: {test_r2*100:.2f}%")
print(f"Average Prediction Error: ±{test_mae:.4f} rating points")

print("\n🎯 KEY FINDINGS:")
print("-" * 70)
print(f"Most Important Feature: {feature_importance.iloc[0]['Feature']}")
print(f"Second Most Important: {feature_importance.iloc[1]['Feature']}")
print(f"Third Most Important: {feature_importance.iloc[2]['Feature']}")

print("\n💡 BUSINESS INSIGHTS:")
print("-" * 70)
print("Based on feature importance analysis:")
print("1. Focus on the top 3 features to improve restaurant ratings")
print("2. These factors have the highest impact on customer satisfaction")
print("3. Restaurant owners should prioritize these areas for investment")

print("\n" + "="*70)
print("✅ ANALYSIS COMPLETED SUCCESSFULLY!")
print("="*70)
# Out:
# ...
# PROJECT SUMMARY - RESTAURANT RATING PREDICTION
# ...
#
# 📊 DATASET INFORMATION:
# ----------------------------------------------------------------------
# Total Restaurants Analyzed: 9,551
# Number of Features Used: 12
# Training Samples: 7,640
# Testing Samples: 1,911
#
# 🤖 MODEL INFORMATION:
# ----------------------------------------------------------------------
# Algorithm: Random Forest Regressor
# Number of Trees: 100
# Maximum Tree Depth: 10
#
# 📈 MODEL PERFORMANCE:
# ----------------------------------------------------------------------
# R² Score: 0.9586
# RMSE: 0.3069
# MAE: 0.2012
#
# Performance Rating: Excellent
# Variance Explained: 95.86%
# Average Prediction Error: ±0.2012 rating points
#
# 🎯 KEY FINDINGS:
# ----------------------------------------------------------------------
# Most Important Feature: Votes
# Second Most Important: Longitude
# Third Most Important: Latitude
#
# 💡 BUSINESS INSIGHTS:
# ----------------------------------------------------------------------
# ...

# %%
# Save predictions
predictions_df = pd.DataFrame({
    'Actual_Rating': y_test.values,
    'Predicted_Rating': y_test_pred,
    'Absolute_Error': np.abs(y_test.values - y_test_pred)
})
predictions_df.to_csv('restaurant_predictions.csv', index=False)
print("✓ Predictions saved to: restaurant_predictions.csv")

# Save feature importance
feature_importance.to_csv('feature_importance.csv', index=False)
print("✓ Feature importance saved to: feature_importance.csv")

# Save model performance summary
performance_summary = pd.DataFrame({
    'Metric': ['R² Score', 'RMSE', 'MAE', 'MSE'],
    'Training': [train_r2, train_rmse, train_mae, train_mse],
    'Testing': [test_r2, test_rmse, test_mae, test_mse]
})
performance_summary.to_csv('model_performance.csv', index=False)
print("✓ Model performance saved to: model_performance.csv")

print("\n📁 All results saved successfully!")
# Out:
# ✓ Predictions saved to: restaurant_predictions.csv
# ✓ Feature importance saved to: feature_importance.csv
# ✓ Model performance saved to: model_performance.csv
#
# 📁 All results saved successfully!
